# %% [markdown]
# <a href="https://colab.research.google.com/github/Juliana-ads-science/README.md/blob/main/Etapa_1_caracteriza%C3%A7%C3%A3o_do_ambiente.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install virtualenv
# !virtualenv venv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 54.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 32.0 MB/s eta 0:00:00
# ...
# created virtual environment CPython3.12.12.final.0-64 in 399ms
#   creator CPython3Posix(dest=/content/venv, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==25.3
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# !source venv/bin/activate

# %%
# %%writefile requirements.txt
# fastapi
# uvicorn[standard]
# psycopg2-binary
# sqlalchemy
# python-dotenv
# alembic
# python-jose
# passlib[bcrypt]
# Out:
# Writing requirements.txt

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 46.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 21.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.6/150.6 kB 12.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 517.7/517.7 kB 35.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 111.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 456.8/456.8 kB 33.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 525.6/525.6 kB 37.4 MB/s eta 0:00:00
# ...

# %%
# !touch app/__init__.py app/main.py
# !touch app/core/config.py app/core/security.py app/core/database.py
# !touch app/routes/__init__.py
# !touch app/models/__init__.py
# !touch app/schemas/__init__.py
# !touch app/services/__init__.py
# Out:
# touch: cannot touch 'app/__init__.py': No such file or directory
# touch: cannot touch 'app/main.py': No such file or directory
# touch: cannot touch 'app/core/config.py': No such file or directory
# touch: cannot touch 'app/core/security.py': No such file or directory
# touch: cannot touch 'app/core/database.py': No such file or directory
# touch: cannot touch 'app/routes/__init__.py': No such file or directory
# touch: cannot touch 'app/models/__init__.py': No such file or directory
# touch: cannot touch 'app/schemas/__init__.py': No such file or directory
# touch: cannot touch 'app/services/__init__.py': No such file or directory
